# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('Salary_Data.csv')
df
# Out:
#        empID  YearsExperience   Age  BTech?  MTech?  PhD?           Name  \
# 0       1001              1.1  30.0       1       1     1      Mr X-ds-1
# 1       1002              1.3  31.0       1       1     1      Mr X-ds-2
# 2       1003              1.5  32.0       1       1     1      Mr X-ds-3
# 3       1004              2.0  33.0       1       1     1      Mr X-ds-4
# 4       1005              2.2  34.0       1       1     1      Mr X-ds-5
# ...      ...              ...   ...     ...     ...   ...            ...
# 13435  14436             10.1  35.0       1       1     1  Mr X-ds-13436
# 13436  14437             11.1  36.0       1       1     1  Mr X-ds-13437
# 13437  14438             12.1  37.0       1       1     1  Mr X-ds-13438
# 13438  14439             13.1  38.0       1       1     1  Mr X-ds-13439
# 13439  14440             14.1  39.0       1       1     1  Mr X-ds-13440
#
#        address       phone branch    Salary
# 0      Kolkata  9890078900   Ruby   39343.0
# ...

# %%
df.isnull().sum()
# Out:
# empID                 0
# YearsExperience       0
# Age                 379
# BTech?                0
# MTech?                0
# PhD?                  0
# Name                  0
# address               0
# phone                 0
# branch                0
# Salary             1920
# dtype: int64

# %%
df['Salary']=df['Salary'].fillna(df['Salary'].mean())
df.dropna(axis='index',how='any',inplace=True)

# %%
df.isnull().sum()
# Out:
# empID              0
# YearsExperience    0
# Age                0
# BTech?             0
# MTech?             0
# PhD?               0
# Name               0
# address            0
# phone              0
# branch             0
# Salary             0
# dtype: int64

# %%
df
# Out:
#        empID  YearsExperience   Age  BTech?  MTech?  PhD?           Name  \
# 0       1001              1.1  30.0       1       1     1      Mr X-ds-1
# 1       1002              1.3  31.0       1       1     1      Mr X-ds-2
# 2       1003              1.5  32.0       1       1     1      Mr X-ds-3
# 3       1004              2.0  33.0       1       1     1      Mr X-ds-4
# 4       1005              2.2  34.0       1       1     1      Mr X-ds-5
# ...      ...              ...   ...     ...     ...   ...            ...
# 13435  14436             10.1  35.0       1       1     1  Mr X-ds-13436
# 13436  14437             11.1  36.0       1       1     1  Mr X-ds-13437
# 13437  14438             12.1  37.0       1       1     1  Mr X-ds-13438
# 13438  14439             13.1  38.0       1       1     1  Mr X-ds-13439
# 13439  14440             14.1  39.0       1       1     1  Mr X-ds-13440
#
#        address       phone branch    Salary
# 0      Kolkata  9890078900   Ruby   39343.0
# ...

# %%
X=df[['YearsExperience']]
Y=df['Salary']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(
    X,Y,test_size=1/3,random_state=0
)

# %%
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([ 57389.65683526,  61735.72755135, 100850.36399616, ...,
#         90419.79427755,  61735.72755135, 105196.43471225], shape=(4354,))

# %%
plt.scatter(X_test,Y_test,color='blue',label="test data")
plt.plot(X_train,regressor.predict(X_train),color="red",label="regressor line")
plt.title("Salary vs Years of experience")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %%
from sklearn import metrics

# R² Score (Coefficient of Determination)
r2 = metrics.r2_score(Y_test, y_pred)

# Mean Absolute Error (MAE)
mae = metrics.mean_absolute_error(Y_test, y_pred)

# Mean Squared Error (MSE)
mse = metrics.mean_squared_error(Y_test, y_pred)

# Root Mean Squared Error (RMSE)
rmse = mse ** 0.5

print("R² Score:", r2)
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# R² Score: 0.37346803507886817
# Mean Absolute Error: 18293.989883632126
# Mean Squared Error: 388404985.7637585
# Root Mean Squared Error: 19707.99294103178

# %%
df=pd.read_csv('ResultAnalysis.csv')
df
# Out:
#      Stud No      Roll No         Name HMTS 3201 INCO 3016 CSEN 3201  \
# 0          1  12621001001    ABCD-ds-1    C (18)     A (0)    B (28)
# 1          2  12621001002    ABCD-ds-2    A (24)     A (0)    E (36)
# 2          3  12621001004    ABCD-ds-3    E (27)     B (0)    O (40)
# 3          4  12621001005    ABCD-ds-4    O (30)     A (0)    O (40)
# 4          5  12621001006    ABCD-ds-5    A (24)     E (0)    E (36)
# ..       ...          ...          ...       ...       ...       ...
# 556      557  12621019052  ABCD-ds-557    B (21)     B (0)    C (24)
# 557      558  12621019053  ABCD-ds-558    E (27)     B (0)    E (36)
# 558      559  12621019054  ABCD-ds-559    A (24)     B (0)    A (32)
# 559      560  12621019055  ABCD-ds-560    A (24)     B (0)    B (28)
# 560      561  12621019056  ABCD-ds-561    C (18)    FA (0)    FA (8)
#
#     CSEN 3202 CSEN 3233 CHEN 3221  CSEN3251  CSEN3252 CSEN3293  SGPA5  SGPA6  \
# ...

# %%
df.isnull().sum()
# Out:
# Stud No      0
# Roll No      0
# Name         0
# HMTS 3201    0
# INCO 3016    0
# CSEN 3201    0
# CSEN 3202    0
# CSEN 3233    0
# CHEN 3221    0
# CSEN3251     0
# CSEN3252     0
# CSEN3293     0
# SGPA5        0
# SGPA6        0
# YGPA3        0
# RESULT       0
# dtype: int64

# %%
X=df[['SGPA5']]
Y=df['SGPA6']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(
    X,Y,test_size=1/3,random_state=0
)

# %%
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([8.52289552, 9.04609716, 6.67961588, 9.04609716, 5.81029623,
#        8.19287602, 8.35386114, 6.74400993, 6.21275903, 8.88511204,
#        6.05177391, 8.21702379, 8.91730906, 6.21275903, 5.98737986,
#        6.74400993, 7.95139834, 8.74022543, 7.79041322, 6.51863076,
#        8.98170311, 8.1043342 , 9.0943927 , 6.26105457, 7.70992066,
#        7.21086678, 7.82261024, 7.32355637, 9.0943927 , 6.67961588,
#        7.72601917, 7.32355637, 7.17866976, 8.3055656 , 7.21086678,
#        7.10622645, 8.17677751, 6.89694579, 7.70992066, 9.0943927 ,
#        8.64363436, 8.24117156, 8.86901353, 8.69192989, 8.00774313,
#        5.98737986, 5.81029623, 9.31977187, 7.85480726, 8.90121055,
#        9.31977187, 8.12848197, 9.48075699, 6.51863076, 9.27147633,
#        6.48643374, 6.90499505, 4.9731736 , 7.17866976, 5.56881855,
#        8.506797  , 5.98737986, 8.24117156, 8.48264924, 7.3718519 ,
#        8.53094477, 4.9731736 , 7.54893553, 8.01579239, 9.04609716,
# ...

# %%
plt.scatter(X_test,Y_test,color='blue',label="test data")
plt.plot(X_train,regressor.predict(X_train),color="red",label="regressor line")
plt.title("SGPA5 vs SGPA6")
plt.xlabel("SGPA5")
plt.ylabel("SGPA6")
plt.legend()
plt.show()

# %%
from sklearn import metrics

# R² Score (Coefficient of Determination)
r2 = metrics.r2_score(Y_test, y_pred)

# Mean Absolute Error (MAE)
mae = metrics.mean_absolute_error(Y_test, y_pred)

# Mean Squared Error (MSE)
mse = metrics.mean_squared_error(Y_test, y_pred)

# Root Mean Squared Error (RMSE)
rmse = mse ** 0.5

print("R² Score:", r2)
print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("Root Mean Squared Error:", rmse)
# Out:
# R² Score: 0.733835328563418
# Mean Absolute Error: 0.4844583949093782
# Mean Squared Error: 0.4084702261221634
# Root Mean Squared Error: 0.6391167546874071
